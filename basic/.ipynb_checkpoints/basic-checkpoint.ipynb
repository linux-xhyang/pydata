# %%
dict = {"1":"hello",
        "2":['w','o','r','l','d']}

print(type(dict))
print(type(dict["2"]))
print(dict.keys())
keys = dict.keys()
for key in keys:
    print(key)
# Out:
# <class 'dict'>
# <class 'list'>
# dict_keys(['1', '2'])
# 1
# 2

# %%
import pandas as pd
datasets = pd.read_csv('~/src/pydata/basic/clone_of_clone_of_clone_of_python_tutorial_-_lessons_3_4_5-query_1-094e586ef161-2018-04-28-09-24-29.csv')
data = datasets
data = data.fillna('')
data[:3]
data['title'].value_counts()[:200]
data['title'].value_counts()[:200].plot(kind='barh')
