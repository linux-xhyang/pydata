# %%
from bokeh.io import output_notebook, show

output_notebook()

import math,numpy as np

X = np.arange(1,10,.1)
Y = [ math.sin(x) for x in X ]
Ym = [ - math.sin(x) for x in X ]

from bokeh.plotting import figure

p = figure(height=300,title='(Python)')
p.title_text_font = 'PilGi'
p.circle(x=X,y=Y,size=X)
p.triangle(x=X,y=Ym,size=X[::-1],color='orange')
p.line(x=X,y=0,line_width=10,color='red',alpha=.3)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9193f886-6432-4177-93a5-ce2dc6464fe7">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="48383e7e-470a-48b1-ad7d-c76ceabfe8c8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("48383e7e-470a-48b1-ad7d-c76ceabfe8c8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '48383e7e-470a-48b1-ad7d-c76ceabfe8c8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"81d7d502-5ee0-4045-899d-2cffedd9443f":{"roots":{"references":[{"attributes":{"plot":{"id":"2a528ee4-5153-40cc-846d-908fa571cb42","subtype":"Figure","type":"Plot"}},"id":"11d9bf46-6f3a-482f-86ec-328c30dc8760","type":"WheelZoomTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4ccbfc02-c9b7-4b61-ae27-9e5991ea3411","type":"Circle"},{"attributes":{"formatter":{"id":"c177a6dc-8212-4a86-a174-56e6c7c5797a","type":"BasicTickFormatter"},"plot":{"id":"2a528ee4-5153-40cc-846d-908fa571cb42","subtype":"Figure","type":"Plot"},"ticker":{"id":"c15b66d3-3488-4767-bb8e-1eaaa2fa4222","type":"BasicTicker"}},"id":"43ec0e8e-7203-4454-92f1-5d742c5a72b8","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"2a528ee4-5153-40cc-846d-908fa571cb42","subtype":"Figure","type":"Plot"},"ticker":{"id":"c15b66d3-3488-4767-bb8e-1eaaa2fa4222","type":"BasicTicker"}},"id":"de95c2b1-297a-4991-be38-e192b00d2f9b","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"fc4feadd-0774-4fd6-92d1-c17c93b9ef99","type":"PanTool"},{"id":"11d9bf46-6f3a-482f-86ec-328c30dc8760","type":"WheelZoomTool"},{"id":"3f067f70-e0dc-49ba-b473-4e356cc92826","type":"BoxZoomTool"},{"id":"91ad459e-0a82-4c03-98b0-4ec79513fc30","type":"SaveTool"},{"id":"fe950453-0616-4bab-aa22-702553810ec6","type":"ResetTool"},{"id":"d6b444ca-6af9-4663-bdb2-34d0d4b12531","type":"HelpTool"}]},"id":"146a28ca-9436-41ed-b40a-68318fdb6b1d","type":"Toolbar"},{"attributes":{"plot":{"id":"2a528ee4-5153-40cc-846d-908fa571cb42","subtype":"Figure","type":"Plot"}},"id":"d6b444ca-6af9-4663-bdb2-34d0d4b12531","type":"HelpTool"},{"attributes":{"plot":{"id":"2a528ee4-5153-40cc-846d-908fa571cb42","subtype":"Figure","type":"Plot"}},"id":"91ad459e-0a82-4c03-98b0-4ec79513fc30","type":"SaveTool"},{"attributes":{"formatter":{"id":"693b751c-128c-476b-90d6-6f530f1e8f8d","type":"BasicTickFormatter"},"plot":{"id":"2a528ee4-5153-40cc-846d-908fa571cb42","subtype":"Figure","type":"Plot"},"ticker":{"id":"7f25391e-b2fc-4c37-a182-55d5450a1b1d","type":"BasicTicker"}},"id":"ddae37a0-365a-400a-9a6b-ba300e8d0856","type":"LinearAxis"},{"attributes":{"data_source":{"id":"645985e0-60e9-47c0-8094-3fec23d44664","type":"ColumnDataSource"},"glyph":{"id":"4ccbfc02-c9b7-4b61-ae27-9e5991ea3411","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"295c6e43-0179-45fd-b66d-0afa497308b7","type":"Circle"},"selection_glyph":null},"id":"86ba0997-1b13-43bf-8c29-fd622fb896a7","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":10},"x":{"field":"x"},"y":{"value":0}},"id":"8b7115f1-5840-40e6-afe3-d2f56d2264b8","type":"Line"},{"attributes":{"plot":{"id":"2a528ee4-5153-40cc-846d-908fa571cb42","subtype":"Figure","type":"Plot"}},"id":"fe950453-0616-4bab-aa22-702553810ec6","type":"ResetTool"},{"attributes":{"below":[{"id":"ddae37a0-365a-400a-9a6b-ba300e8d0856","type":"LinearAxis"}],"left":[{"id":"43ec0e8e-7203-4454-92f1-5d742c5a72b8","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"ddae37a0-365a-400a-9a6b-ba300e8d0856","type":"LinearAxis"},{"id":"7bc10f22-2d09-44e9-ac94-839a4f7cf8e8","type":"Grid"},{"id":"43ec0e8e-7203-4454-92f1-5d742c5a72b8","type":"LinearAxis"},{"id":"de95c2b1-297a-4991-be38-e192b00d2f9b","type":"Grid"},{"id":"f46133f1-ce86-4505-b2da-6a00779e39be","type":"BoxAnnotation"},{"id":"86ba0997-1b13-43bf-8c29-fd622fb896a7","type":"GlyphRenderer"},{"id":"88d21217-f7f8-4731-9708-d37975c64731","type":"GlyphRenderer"},{"id":"fd8782b7-b84c-4189-9bad-bf511f92117a","type":"GlyphRenderer"}],"title":{"id":"df199ad8-4428-4701-90df-8030e12737ad","type":"Title"},"tool_events":{"id":"90423287-0939-4b87-999f-e32e5c078d7b","type":"ToolEvents"},"toolbar":{"id":"146a28ca-9436-41ed-b40a-68318fdb6b1d","type":"Toolbar"},"x_range":{"id":"b279dac0-cf66-41ed-b693-823c8a2023cd","type" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>
